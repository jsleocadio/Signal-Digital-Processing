# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

filename = 'https://raw.githubusercontent.com/jsleocadio/Signal-Digital-Processing/main/Project_01/2022-09-28_Covid-Bra.csv'
df = pd.read_csv(filename)

df.head(10)
# Out:
#   iso_code      continent location        date  total_cases  new_cases  \
# 0      BRA  South America   Brazil  2020-02-26            1        1.0
# 1      BRA  South America   Brazil  2020-02-27            1        0.0
# 2      BRA  South America   Brazil  2020-02-28            1        0.0
# 3      BRA  South America   Brazil  2020-02-29            2        1.0
# 4      BRA  South America   Brazil  2020-03-01            2        0.0
# 5      BRA  South America   Brazil  2020-03-02            2        0.0
# 6      BRA  South America   Brazil  2020-03-03            2        0.0
# 7      BRA  South America   Brazil  2020-03-04            4        2.0
# 8      BRA  South America   Brazil  2020-03-05            4        0.0
# 9      BRA  South America   Brazil  2020-03-06           13        9.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
# 5               0.286           NaN         NaN                  NaN  ...
# 6               0.286           NaN         NaN                  NaN  ...
# 7               0.429           NaN         NaN                  NaN  ...
# 8               0.429           NaN         NaN                  NaN  ...
# 9               1.714           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0            10.1          17.9                     NaN
# 1            10.1          17.9                     NaN
# 2            10.1          17.9                     NaN
# 3            10.1          17.9                     NaN
# 4            10.1          17.9                     NaN
# 5            10.1          17.9                     NaN
# 6            10.1          17.9                     NaN
# 7            10.1          17.9                     NaN
# 8            10.1          17.9                     NaN
# 9            10.1          17.9                     NaN
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         2.2            75.88                    0.765
# 1                         2.2            75.88                    0.765
# 2                         2.2            75.88                    0.765
# 3                         2.2            75.88                    0.765
# 4                         2.2            75.88                    0.765
# 5                         2.2            75.88                    0.765
# 6                         2.2            75.88                    0.765
# 7                         2.2            75.88                    0.765
# 8                         2.2            75.88                    0.765
# 9                         2.2            75.88                    0.765
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                7049.6                         3.31
# 4                                   NaN                          NaN
# 5                                   NaN                          NaN
# 6                                   NaN                          NaN
# 7                                   NaN                          NaN
# 8                                   NaN                          NaN
# 9                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3              5.25                                32.891915
# 4               NaN                                      NaN
# 5               NaN                                      NaN
# 6               NaN                                      NaN
# 7               NaN                                      NaN
# 8               NaN                                      NaN
# 9               NaN                                      NaN
#
# [10 rows x 67 columns]

# %%
Ind = ~np.isnan(df.new_deaths)
df = df[Ind]

df.head(10)
# Out:
#    iso_code      continent location        date  total_cases  new_cases  \
# 20      BRA  South America   Brazil  2020-03-17          321      121.0
# 21      BRA  South America   Brazil  2020-03-18          372       51.0
# 22      BRA  South America   Brazil  2020-03-19          621      249.0
# 23      BRA  South America   Brazil  2020-03-20          793      172.0
# 24      BRA  South America   Brazil  2020-03-21         1021      228.0
# 25      BRA  South America   Brazil  2020-03-22         1546      525.0
# 26      BRA  South America   Brazil  2020-03-23         1924      378.0
# 27      BRA  South America   Brazil  2020-03-24         2247      323.0
# 28      BRA  South America   Brazil  2020-03-25         2554      307.0
# 29      BRA  South America   Brazil  2020-03-26         2985      431.0
#
#     new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 20              41.429           1.0         1.0                  NaN  ...
# 21              47.714           3.0         2.0                  NaN  ...
# 22              81.286           6.0         3.0                  NaN  ...
# 23              91.714          11.0         5.0                  NaN  ...
# 24             124.286          15.0         4.0                  NaN  ...
# 25             197.714          25.0        10.0                3.571  ...
# 26             246.286          34.0         9.0                4.857  ...
# 27             275.143          46.0        12.0                6.429  ...
# 28             311.714          59.0        13.0                8.000  ...
# 29             337.714          77.0        18.0               10.143  ...
#
#     female_smokers  male_smokers  handwashing_facilities  \
# 20            10.1          17.9                     NaN
# 21            10.1          17.9                     NaN
# 22            10.1          17.9                     NaN
# 23            10.1          17.9                     NaN
# 24            10.1          17.9                     NaN
# 25            10.1          17.9                     NaN
# 26            10.1          17.9                     NaN
# 27            10.1          17.9                     NaN
# 28            10.1          17.9                     NaN
# 29            10.1          17.9                     NaN
#
#     hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 20                         2.2            75.88                    0.765
# 21                         2.2            75.88                    0.765
# 22                         2.2            75.88                    0.765
# 23                         2.2            75.88                    0.765
# 24                         2.2            75.88                    0.765
# 25                         2.2            75.88                    0.765
# 26                         2.2            75.88                    0.765
# 27                         2.2            75.88                    0.765
# 28                         2.2            75.88                    0.765
# 29                         2.2            75.88                    0.765
#
#     excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 20                                   NaN                          NaN
# 21                                   NaN                          NaN
# 22                                   NaN                          NaN
# 23                                   NaN                          NaN
# 24                                   NaN                          NaN
# 25                                   NaN                          NaN
# 26                                   NaN                          NaN
# 27                                   NaN                          NaN
# 28                                   NaN                          NaN
# 29                                   NaN                          NaN
#
#     excess_mortality  excess_mortality_cumulative_per_million
# 20               NaN                                      NaN
# 21               NaN                                      NaN
# 22               NaN                                      NaN
# 23               NaN                                      NaN
# 24               NaN                                      NaN
# 25               NaN                                      NaN
# 26               NaN                                      NaN
# 27               NaN                                      NaN
# 28               NaN                                      NaN
# 29               NaN                                      NaN
#
# [10 rows x 67 columns]

# %%
from matplotlib.axis import XTick

t = df.date
S = df.new_deaths
plt.style.use('seaborn-dark')
fig = plt.figure(figsize=(10,6))

lin = plt.plot(t,S);
plt.xlabel('$Date$',fontdict={'fontsize':12})
plt.ylabel('New deaths',fontdict={'fontsize':12})
plt.title('New deaths from COVID-19',fontdict={'fontsize':18,'fontweight':'bold'})
fig.show()

# %%
N = 7
h = np.ones(N)/N
y = np.convolve(S, h)
y = y[0:len(S)]

# %%
plt.style.use('seaborn-dark')
fig = plt.figure(figsize=(10,6))
lin = plt.plot(t,y)
plt.xlabel('$Date$',fontdict={'fontsize':12})
plt.ylabel('Moving Average',fontdict={'fontsize':12})
plt.title('Moving average from deaths by COVID-19',fontdict={'fontsize':18,'fontweight':'bold'})
fig.show()

# %%
plt.style.use('seaborn-dark')
fig = plt.figure(figsize=(10,6))
lin1 = plt.plot(t,S)
lin2 = plt.plot(t,y)
plt.xlabel('$Date$',fontdict={'fontsize':12})
plt.ylabel('New deaths',fontdict={'fontsize':12})
plt.title('New deaths from COVID-19 with Moving Average',fontdict={'fontsize':18,'fontweight':'bold'})
fig.show()
